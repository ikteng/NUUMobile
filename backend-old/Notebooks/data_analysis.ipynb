# %% [markdown]
# We need to predict the records with missing data whether they are return or not return based on records that are confirmed return.

# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# load the excel sheet into a Dataframe
xls = pd.ExcelFile("UW_Churn_Pred_Data.xls")
print(f"Sheet Names: {xls.sheet_names}")
# Out:
# Sheet Names: ['Data', 'Legend', 'N10', 'B30 Pro', 'Data Before Feb 13']

# %%
# Load the data sheet
data = pd.read_excel(xls, sheet_name="Data")

# %%
# show the first 5 rows of the dataset
print(data.head())
# Out:
#     Sale Channel     Model Warranty       Feedback           Verification  \
# 0  B2C 3rd party       B20      Yes  Amazon Return  no damages, no issues
# 1  B2C 3rd party  A23 Plus      Yes  Amazon Return  no damages, no issues
# 2  B2C 3rd party       A15      Yes            NaN                    NaN
# 3  B2C 3rd party  A23 Plus      Yes  Amazon Return  no damages, no issues
# 4  B2C 3rd party       B20      Yes  Amazon Return  no damages, no issues
#
#   Defect / Damage type  Responsible Party    Type  \
# 0            No defect  Customer: Remorse  Return
# 1            No defect  Customer: Remorse  Return
# 2                  NaN                NaN     NaN
# 3            No defect  Customer: Remorse  Return
# 4            No defect  Customer: Remorse  Return
#
#   Spare Parts Used if returned Final Status  ...  Bluetooth (# of pairs)  \
# 0                           No     Refurb A  ...                       1
# 1                           No     Refurb B  ...                       0
# 2                          NaN          NaN  ...                       5
# 3                           No     Refurb B  ...                       0
# 4                           No     Refurb B  ...                       1
#
#    Wifi/Internet Connection Wallpaper Registered Email last boot - activate  \
# 0                      True         1              1.0             0.000000
# 1                      True         1              1.0             0.000023
# 2                      True         2              NaN             0.000000
# 3                      True         1              0.0             0.151493
# 4                      True         0              1.0             0.000000
#
#   last boot - interval        interval date      last bootl date  \
# 0             0.000000  2024-11-18 00:52:52  2024-11-18 00:52:52
# 1             0.000000  2024-11-18 00:35:59  2024-11-18 00:35:59
# 2             0.000000  2024-11-17 23:42:12  2024-11-17 23:42:12
# 3             0.151481  2024-11-17 23:28:58  2024-11-18 03:07:06
# 4             0.000000  2024-11-17 21:50:16  2024-11-17 21:50:16
#
#          activate date  Age Range
# 0  2024-11-18 00:52:52      30-40
# 1  2024-11-18 00:35:57      30-40
# 2  2024-11-17 23:42:12      20-30
# 3  2024-11-17 23:28:57      20-30
# 4  2024-11-17 21:50:16      40-50
#
# [5 rows x 28 columns]

# %%
# Display basic info about the data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4349 entries, 0 to 4348
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sale Channel                  4349 non-null   object
#  1   Model                         4347 non-null   object
#  2   Warranty                      4342 non-null   object
#  3   Feedback                      2677 non-null   object
#  4   Verification                  2680 non-null   object
#  5   Defect / Damage type          2678 non-null   object
#  6   Responsible Party             2677 non-null   object
#  7   Type                          2681 non-null   object
#  8   Spare Parts Used if returned  2674 non-null   object
#  9   Final Status                  2681 non-null   object
#  10  Customer Service Requested    4349 non-null   int64
#  11  Number of Sim                 4349 non-null   int64
#  12  Sim Country                   4349 non-null   object
#  13  Slot 1                        4349 non-null   object
#  14  Slot 2                        4349 non-null   object
#  15  Sim Card                      4349 non-null   object
#  16  Screen Usage (s)              4349 non-null   int64
#  17  App Usage (s)                 4349 non-null   object
#  18  Bluetooth (# of pairs)        4349 non-null   int64
#  19  Wifi/Internet Connection      4349 non-null   bool
#  20  Wallpaper                     4349 non-null   int64
#  21  Registered Email              2681 non-null   float64
#  22  last boot - activate          4349 non-null   float64
#  23  last boot - interval          4349 non-null   float64
#  24  interval date                 4349 non-null   object
#  25  last bootl date               4349 non-null   object
#  26  activate date                 4349 non-null   object
#  27  Age Range                     4349 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(19)
# memory usage: 921.7+ KB
# None

# %% [markdown]
# # Legends of Each Column

# %%
# Load the Legend sheet with no header
legend = pd.read_excel(xls, sheet_name="Legend", header=None)

# Rename columns for clarity
legend.columns = ["Column", "Description"]

# Display the legend properly
print(legend.to_string(index=False))  # Removes index for cleaner display
# Out:
#                       Column                                                  Description
#                 Sale Channel                                     Channels the device sold
#                        Model                                                 Device model
#                     Warranty            If the customer purchased warranty for the device
#                     Feedback                                            Customer feedback
#                 Verification                        Verified issues from our testing team
#         Defect / Damage type                                                  Damage type
#            Responsible Party                        The reason why the device is returned
#                         Type                                  Return or Repair the device
# Spare Parts Used if returned                         If there any used parts from the box
#                 Final Status The device may be refurbed or sent back (Return means Churn)
#   Customer Service Requested                           How many times the CS been reached
#                Number of Sim                    Number of SIM card detected in the device
#                  Sim Country                    Carrier origin of the firt slot sim card
#                       Slot 1                                                First carrier
#                       Slot 2                                               Second carrier
#                     Sim Card                                                Sim card info
#             Screen Usage (s)                                             Screen time used
#                 App Uage (s)                                               Favorite Apps
#       Bluetooth (# of pairs)                                     How many Bluetooth pairs
#     Wifi/Internet Connection                   If the device is connected to the internet
#                    Wallpaper                How many times the wallpaper has been changed
#             Registered Email                     If the customer registered email with us
#         last boot - activate                     last boot date minus the activation date
#         last boot - interval                 last boot date minus the alive detected date
#                interval date                    the last date the device been detected ON
#               last boot date                           The date when last reboot happened
#                activate date                      The date when the device been activated
#                    Age Range                              Approximated customer age range

# %%
# check for missing values
print(f"Missing Values:\n{data.isnull().sum()}")
# Out:
# Missing Values:
# Sale Channel                       0
# Model                              2
# Warranty                           7
# Feedback                        1672
# Verification                    1669
# Defect / Damage type            1671
# Responsible Party               1672
# Type                            1668
# Spare Parts Used if returned    1675
# Final Status                    1668
# Customer Service Requested         0
# Number of Sim                      0
# Sim Country                        0
# Slot 1                             0
# Slot 2                             0
# Sim Card                           0
# Screen Usage (s)                   0
# App Usage (s)                      0
# Bluetooth (# of pairs)             0
# Wifi/Internet Connection           0
# Wallpaper                          0
# Registered Email                1668
# last boot - activate               0
# last boot - interval               0
# interval date                      0
# last bootl date                    0
# activate date                      0
# Age Range                          0
# dtype: int64

# %% [markdown]
# This shows that there are missing data!

# %%
# check for duplicates
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
categorical_features = data.select_dtypes(include=['object', 'bool']).columns.tolist()
numerical_features = data.select_dtypes(include=['int64', 'float64']).columns.tolist()

print("Categorical Features:", categorical_features)
print("Numerical Features:", numerical_features)
# Out:
# Categorical Features: ['Sale Channel', 'Model', 'Warranty', 'Feedback', 'Verification', 'Defect / Damage type', 'Responsible Party', 'Type', 'Spare Parts Used if returned', 'Final Status', 'Sim Country', 'Slot 1', 'Slot 2', 'Sim Card', 'App Usage (s)', 'Wifi/Internet Connection', 'interval date', 'last bootl date', 'activate date', 'Age Range']
# Numerical Features: ['Customer Service Requested', 'Number of Sim', 'Screen Usage (s)', 'Bluetooth (# of pairs)', 'Wallpaper', 'Registered Email', 'last boot - activate', 'last boot - interval']

# %% [markdown]
# # Analyzing Categorical Features

# %%
# Function to clean carrier info by removing everything in parentheses
def clean_carrier_label(label):
    # Use regular expression to remove content within parentheses and the parentheses themselves
    return re.sub(r'\s\([^)]+\)', '', label)

# %%
# Define all categorical features to include in the plot
features = [
    "Sale Channel", "Warranty", "Defect / Damage type",
    "Responsible Party", "Type", "Final Status", "Wifi/Internet Connection", "Age Range",
    "Spare Parts Used if returned", "Sim Country"
]

# Calculate the number of rows and columns based on the number of features
num_features = len(features)
num_cols = 2  # Adjust as needed for better layout
num_rows = (num_features + num_cols - 1) // num_cols  # Round up to ensure enough rows

# Create a subplot with enough rows and columns
plt.figure(figsize=(15, num_rows * 5))

for i, feature in enumerate(features, 1):
    # Count unique values and sort by frequency
    if feature == 'Spare Parts Used if returned':
        # Clean the labels by standardizing the case (e.g., "Yes", "No")
        data[feature] = data[feature].str.strip().str.capitalize()
        
    elif feature == 'Sim Country':
        # Apply the cleaning function to the feature's values
        cleaned_labels = data[feature].apply(clean_carrier_label)
        value_counts = cleaned_labels.value_counts().sort_values(ascending=False)
    else:
        value_counts = data[feature].value_counts().sort_values(ascending=False)

    # Display value counts
    print(f"--- {feature} ---")
    print(value_counts, "\n")

    # Plot the distribution in the respective subplot
    plt.subplot(num_rows, num_cols, i)
    value_counts.plot(kind='bar', title=f'{feature} Distribution')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')  # Rotate labels for readability

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# --- Sale Channel ---
# Sale Channel
# B2C 3rd party      3447
# B2C NUU Website     577
# B2B                 325
# Name: count, dtype: int64
#
# --- Warranty ---
# Warranty
# Yes    3950
# No      392
# Name: count, dtype: int64
#
# --- Defect / Damage type ---
# Defect / Damage type
# No defect                   2177
# Hardware                     281
# Display or TP                 80
# Microphone/Speaker            40
# Power (non battery)           36
# Software                      33
# Battery                       12
# Camera                         8
# Buttons Physical               5
# Receive/Transmit/Antenna       4
# Swollen Battery and LCD        2
# Name: count, dtype: int64
#
# --- Responsible Party ---
# Responsible Party
# Customer: Remorse      2148
# Factory: Defective      245
# Customer: Damaged       188
# Tested but No Issue      72
# Paid RMA                 24
# Name: count, dtype: int64
#
# --- Type ---
# Type
# Return    2292
# Repair     389
# Name: count, dtype: int64
#
# --- Final Status ---
# Final Status
# Refurb B                                              1543
# Refurb A                                               426
# SBC                                                    264
# New                                                    225
# Write-off                                               66
# Write-off - Replacement Sent                            59
# Defective - Pending to repair and replacement sent      33
# Defective - Pending ro repair                           26
# B2B-TBD                                                 24
# Send back to HK                                         11
# Customer disposal                                        3
# Marketing Sample                                         1
# Name: count, dtype: int64
#
# --- Wifi/Internet Connection ---
# Wifi/Internet Connection
# True     3512
# False     837
# Name: count, dtype: int64
#
# --- Age Range ---
# Age Range
# 30-40    1558
# 20-30    1179
# 70-80     418
# 60-70     403
# 40-50     399
# 50-60     358
# 80-90      34
# Name: count, dtype: int64
#
# --- Spare Parts Used if returned ---
# Age Range
# 30-40    1558
# 20-30    1179
# 70-80     418
# 60-70     403
# 40-50     399
# 50-60     358
# 80-90      34
# Name: count, dtype: int64
#
# --- Sim Country ---
# Sim Country
# uninserted      2300
# China            195
# Canada           183
# India            183
# Australia        178
# Russia           176
# Germany          176
# UK               171
# Japan            169
# USA              160
# France           159
# Brazil           159
# South Africa     140
# Name: count, dtype: int64

# %%
# Create a subplot with 1 row and 2 columns
plt.figure(figsize=(15, 8))

# List of features to plot
features = ['Slot 1', 'Slot 2']

for i, feature in enumerate(features, 1):
    # Count unique values and sort by frequency
    value_counts = data[feature].value_counts().sort_values(ascending=False)

    # Display value counts
    print(f"--- {feature} ---")
    print(value_counts, "\n")

    # Apply the cleaning function to the feature's values
    cleaned_labels = data[feature].apply(clean_carrier_label)

    # Count unique values and sort by frequency
    value_counts = cleaned_labels.value_counts().sort_values(ascending=False)

    # Plot the distribution in the respective subplot
    plt.subplot(1, 2, i)
    value_counts.plot(kind='bar', title=f'{feature} Distribution')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')  # Rotate labels for readability

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# --- Slot 1 ---
# Slot 1
# uninserted             2300
# T-Mobile (262-01)        76
# NTT Docomo (440-10)      74
# CMCC (460-00)            69
# Rogers (302-720)         67
# Orange (208-01)          67
# Vodafone (505-03)        67
# Unicom (460-01)          67
# Vodafone (404-20)        65
# TIM (724-11)             62
# Verizon (310-012)        61
# Airtel (404-45)          61
# Bell (302-610)           61
# MegaFon (250-02)         59
# Telecom (460-03)         59
# Beeline (250-99)         59
# MTS (250-01)             58
# EE (234-30)              58
# Jio (404-10)             57
# Vodafone (234-15)        57
# Telstra (505-01)         57
# O2 (234-10)              56
# Vodacom (655-01)         56
# Telus (302-220)          55
# Optus (505-02)           54
# AT&T (310-410)           54
# Vivo (724-10)            51
# O2 (262-03)              51
# Vodafone (262-02)        49
# SoftBank (440-20)        48
# au (440-30)              47
# MTN (655-10)             46
# Bouygues (208-20)        46
# SFR (208-10)             46
# Claro (724-05)           46
# T-Mobile (310-260)       45
# Cell C (655-07)          38
# Name: count, dtype: int64
#
# --- Slot 2 ---
# Slot 2
# uninserted             3540
# au (440-30)              32
# Jio (404-10)             31
# MegaFon (250-02)         29
# SFR (208-10)             29
# NTT Docomo (440-10)      29
# Telus (302-220)          27
# O2 (262-03)              26
# Unicom (460-01)          26
# T-Mobile (262-01)        26
# Optus (505-02)           25
# CMCC (460-00)            25
# Verizon (310-012)        25
# Vodafone (234-15)        24
# MTS (250-01)             24
# Vodafone (262-02)        23
# AT&T (310-410)           23
# TIM (724-11)             23
# T-Mobile (310-260)       23
# Vodafone (505-03)        23
# Rogers (302-720)         23
# Telstra (505-01)         22
# EE (234-30)              22
# O2 (234-10)              21
# Claro (724-05)           21
# Bell (302-610)           21
# MTN (655-10)             20
# Telecom (460-03)         19
# Bouygues (208-20)        19
# Vivo (724-10)            19
# Cell C (655-07)          17
# Vodafone (404-20)        17
# SoftBank (440-20)        16
# Vodacom (655-01)         16
# Airtel (404-45)          15
# Beeline (250-99)         15
# Orange (208-01)          13
# Name: count, dtype: int64

# %%
feature = 'Model'

# Clean and standardize the 'Model' column
data[feature] = data[feature].str.strip().str.replace(" ", "", regex=True).str.title()

# Count unique models and sort by frequency
value_counts = data[feature].value_counts().sort_values(ascending=False)

# Display the cleaned counts
print(value_counts)

# Plot the horizontal bar chart for better readability
plt.figure(figsize=(10, 8))
value_counts.plot(kind='barh', title=f'{feature} Distribution')
plt.xlabel('Count')
plt.ylabel(feature)
plt.gca().invert_yaxis()  # Invert y-axis for descending order
plt.show()
# Out:
# Model
# A23Plus     1641
# B20          602
# A15          598
# A25          417
# B15          225
# B30Pro       194
# B10          174
# F4L          146
# Earbudsa      78
# X6P           73
# Earbudsb      56
# A11L          52
# B20Tpu        38
# Tab8Plus      23
# A10L          10
# N10            5
# B30            4
# Tab10          4
# A9L            3
# G5             2
# A23            2
# Name: count, dtype: int64

# %%
# Verification & Feedback
features = ['Verification', 'Feedback']

# Create a subplot with 1 row and 2 columns
plt.figure(figsize=(15, 8))

for i, feature in enumerate(features, 1):
    # Count unique values and sort by frequency
    value_counts = data[feature].value_counts().sort_values(ascending=False)
    
    # Print the value counts for the current feature
    print(f"--- {feature} ---")
    print(value_counts, "\n")

    # Define a minimum count threshold (e.g., categories with less than 30 occurrences are small)
    min_count = 30
    small_categories = value_counts[value_counts < min_count]
    
    # Replace small categories with 'Others'
    value_counts = value_counts[~value_counts.index.isin(small_categories.index)]
    value_counts['Others'] = small_categories.sum()
    
    # Plot pie chart in the respective subplot (i.e., 1st and 2nd column)
    plt.subplot(1, 2, i)
    value_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=False)
    plt.title(f'{feature} Distribution')
    plt.ylabel('')  # Hides the y-label for a cleaner pie chart

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# --- Verification ---
# Verification
# no damages, no issues                                                                            1877
# unopened packaging                                                                                174
# opened packaging                                                                                   59
# defective charger port                                                                             41
# damaged charger port                                                                               25
#                                                                                                  ...
# Device is not compatible with service provider/ apps restart                                        1
# device only vibrates when powering on, no display                                                   1
# Battery swollen and back glass cracked                                                              1
# customer damage, back cover has been removed by the customer to cause damage to the side keys       1
# BwP testing                                                                                         1
# Name: count, Length: 297, dtype: int64
#
# --- Feedback ---
# Feedback
# Amazon Return                           2088
# Website Return                           122
# Premier Wireless Return                   50
# device doesn't charge                     24
# device will not charge                    20
#                                         ...
# device freezes and restarts randomly       1
# device is charging slow                    1
# Walmart Return                             1
# Vendor Return                              1
# BwP testing                                1
# Name: count, Length: 241, dtype: int64

# %% [markdown]
# Note: There are some categories that are meant the same thing! Example: "device doesn't charge" and "device will not charge" means the same thing! Would need to break it down and merge it together!

# %%
# Function to parse the app usage string and extract the app and time
def extract_app_usage(app_usage_str):
    if isinstance(app_usage_str, str):  # Only process if it's a string
        app_usage_list = app_usage_str.split(', ')  # Split the string by commas
        app_dict = {}
        for app in app_usage_list:
            app_name, usage_time = app.split(' ')  # Split the app name and usage time
            app_dict[app_name] = int(usage_time.replace('s', ''))  # Convert usage time to int and remove 's'
        return app_dict
    else:
        return {}

# Apply the function to each row and aggregate the results
all_apps_usage = {}
for app_usage_str in data['App Uage (s)']:
    app_dict = extract_app_usage(app_usage_str)
    for app, usage in app_dict.items():
        if app in all_apps_usage:
            all_apps_usage[app] += usage
        else:
            all_apps_usage[app] = usage

# Sort the apps by usage time in descending order
sorted_apps_usage = sorted(all_apps_usage.items(), key=lambda x: x[1], reverse=True)

# Display the sorted apps with their usage time
for app, usage in sorted_apps_usage[:10]:  # Display top 10 most used apps
    print(f"{app}: {usage} seconds of usage")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\liawi\Documents\GitHub\NUUMobile1\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'App Uage (s)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 15
#      13 # Apply the function to each row and aggregate the results
#      14 all_apps_usage = {}
# ---> 15 for app_usage_str in data['App Uage (s)']:
#      16     app_dict = extract_app_usage(app_usage_str)
#      17     for app, usage in app_dict.items():
#
# File c:\Users\liawi\Documents\GitHub\NUUMobile1\venv\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\liawi\Documents\GitHub\NUUMobile1\venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'App Uage (s)'

# %% [markdown]
# # Analyzing Numerical Features

# %%
# Summary statistics for numerical features
print("Numerical Features Summary:")
print(data.describe())
# Out:
# Numerical Features Summary:
#        Customer Service Requested  Number of Sim  Screen Usage (s)  \
# count                 4349.000000    4349.000000       4349.000000
# mean                     0.414808       0.657163      28528.007358
# std                      0.819452       0.772966      13222.610508
# min                      0.000000       0.000000          0.000000
# 25%                      0.000000       0.000000      17972.000000
# 50%                      0.000000       0.000000      28972.000000
# 75%                      1.000000       1.000000      39898.000000
# max                      5.000000       2.000000      49975.000000
#
#        Bluetooth (# of pairs)    Wallpaper  Registered Email  \
# count             4349.000000  4349.000000       2681.000000
# mean                 1.752357     6.581283          0.829914
# std                  1.483138    28.739570          0.375778
# min                  0.000000     0.000000          0.000000
# 25%                  0.000000     0.000000          1.000000
# 50%                  2.000000     1.000000          1.000000
# 75%                  3.000000     1.000000          1.000000
# max                  6.000000   224.000000          1.000000
#
#        last boot - activate  last boot - interval
# count           4349.000000           4349.000000
# mean              44.884767              2.337189
# std               38.616904             15.964296
# min                0.000000            -29.454618
# 25%                1.912037             -2.018113
# 50%               43.157593              0.202164
# 75%               84.039016              1.539468
# max              121.541678             97.202407

# %%
# Plot histograms for numerical features
data[numerical_features].hist(bins=20, figsize=(15, 10), color='lightblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
# Correlation matrix for numerical features
corr_matrix = data[numerical_features].corr()

print(corr_matrix)

# Plotting the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title("Correlation Matrix of Numerical Features")
plt.show()
# Out:
#                             Customer Service Requested  Number of Sim  \
# Customer Service Requested                    1.000000      -0.002731
# Number of Sim                                -0.002731       1.000000
# Screen Usage (s)                              0.046571       0.074657
# Bluetooth (# of pairs)                        0.003359       0.039073
# Wallpaper                                    -0.101590      -0.170115
# Registered Email                              0.103429       0.166137
# last boot - activate                          0.040474       0.066961
# last boot - interval                         -0.013515      -0.006934
#
#                             Screen Usage (s)  Bluetooth (# of pairs)  \
# Customer Service Requested          0.046571                0.003359
# Number of Sim                       0.074657                0.039073
# Screen Usage (s)                    1.000000                0.131372
# Bluetooth (# of pairs)              0.131372                1.000000
# Wallpaper                          -0.431291               -0.237125
# Registered Email                    0.417628                0.234781
# last boot - activate                0.112623                0.078078
# last boot - interval                0.032402                0.007733
#
#                             Wallpaper  Registered Email  last boot - activate  \
# Customer Service Requested  -0.101590          0.103429              0.040474
# Number of Sim               -0.170115          0.166137              0.066961
# Screen Usage (s)            -0.431291          0.417628              0.112623
# Bluetooth (# of pairs)      -0.237125          0.234781              0.078078
# Wallpaper                    1.000000         -0.570290             -0.232828
# Registered Email            -0.570290          1.000000              0.255668
# last boot - activate        -0.232828          0.255668              1.000000
# last boot - interval        -0.029080          0.114034              0.120582
#
#                             last boot - interval
# Customer Service Requested             -0.013515
# Number of Sim                          -0.006934
# Screen Usage (s)                        0.032402
# Bluetooth (# of pairs)                  0.007733
# Wallpaper                              -0.029080
# Registered Email                        0.114034
# last boot - activate                    0.120582
# last boot - interval                    1.000000

# %% [markdown]
# ### Insights from the Correlation Matrix
# This correlation matrix shows how strongly numerical features are related to each other. The values range from -1 to 1:
# - 1.0 → Perfect positive correlation (as one increases, the other increases).
# - -1.0 → Perfect negative correlation (as one increases, the other decreases).
# - 0.0 → No correlation.

# %% [markdown]
# ### Key Takeaways:
# Strongest Positive Correlations:
# - Registered Email & Wallpaper (-0.570): This is a strong negative correlation, meaning that users who have a registered email tend to have fewer wallpapers, and vice versa.
# - Registered Email & Screen Usage (s) (0.418): Users with a registered email tend to have higher screen usage.
# - Wallpaper & Screen Usage (s) (-0.431): People with more wallpapers tend to have lower screen usage.
#
# Moderate Positive Correlations:
# - Registered Email & last boot - activate (0.256): Users with registered emails have a higher number of boots since activation.
# - Bluetooth (# of pairs) & Screen Usage (s) (0.131): More Bluetooth pairings correlate slightly with higher screen usage.
#
# Weak or No Correlation:
# - Customer Service Requested has very low correlations with other features, meaning it is not strongly influenced by the other numerical variables.
# - Number of Sim does not correlate strongly with any variable.
# - last boot - interval does not have significant relationships with other features.
#
# Negative Correlations:
# - Wallpaper has negative correlations with multiple features, suggesting that users with more wallpapers may behave differently (e.g., less screen time, less frequent reboots).
